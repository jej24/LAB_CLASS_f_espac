# %% [markdown]
# <a href="https://colab.research.google.com/github/jej24/LAB_CLASS_f_espac/blob/master/Lab1_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os

path='/content/drive/My Drive/PDI/RUIDO/'
os.chdir(path)
# !pwd
# %matplotlib inline
# Out:
# /content/drive/My Drive/PDI/RUIDO

# %%
def display22(a,b,title1="Orginial", title2="Edited"):
    plt.figure(figsize=(10,10))
    plt.subplot(121), plt.imshow(a, cmap='gray'),plt.title(title1)
    plt.xticks([]),plt.yticks([])
    plt.subplot(122), plt.imshow(b, cmap='gray'), plt.title(title2)
    plt.xticks([]),plt.yticks([])
    plt.show()

# %%
def display4(a, b, c, d, title1= "Original", title2 = "Editado", title3 = "Editado1", title4 = "Editado2"):
   plt.figure(figsize=(20,20))
   plt.subplot(141), plt.imshow(a, cmap='gray'), plt.title(title1)
   plt.xticks([]), plt.yticks([])
   plt.subplot(142), plt.imshow(b, cmap='gray'), plt.title(title2)
   plt.xticks([]), plt.yticks([])
   plt.subplot(143), plt.imshow(c, cmap='gray'), plt.title(title3)
   plt.xticks([]), plt.yticks([])
   plt.subplot(144), plt.imshow(d, cmap='gray'), plt.title(title4)
   plt.xticks([]), plt.yticks([])
   plt.show()

# %%
def readRGB(imgPath):
    img = cv2.imread(imgPath)
    img =cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    return img

# %%
img = cv2.imread('INTER.jpg',0)
f = np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))


display22(img, magnitude_spectrum, "Input Image", "Magnitude Spectrum")

# %% [markdown]
# #corelacion  solo desplazo
#
# #combolucion invierto el kernel y desplazo

# %% [markdown]
# ***MEDIAN FILTER ***

# %%
# READ DE IMAGE

img = cv2.imread("saltlgle.png",0)

#apply the 3x3 median filter on the image

median = cv2.medianBlur(img, 3)

#display image

display22(img, median)

# %%
# READ DE IMAGE

img = cv2.imread("saltlgle.png",0)

#apply the 3x3 median filter on the image

median = cv2.medianBlur(img, 3)
median = cv2.medianBlur(median, 3)
median = cv2.medianBlur(median, 3)
median = cv2.medianBlur(median, 5)

#display image

display22(img, median)

# %%
# READ DE IMAGE

img = cv2.imread("saltpepper.png",0)

#apply the 3x3 median filter on the image

median = cv2.medianBlur(img, 3)
median = cv2.medianBlur(median, 3)
median = cv2.medianBlur(median, 3)
median = cv2.medianBlur(median, 5)
median = cv2.medianBlur(median, 5)
median = cv2.medianBlur(median, 5)
median = cv2.medianBlur(median, 7)

#display image

display22(img, median)

# %% [markdown]
# ***FILTRO DE SHARPENING***

# %%
# Reading in and displaying our image
img = cv2.imread("INTER.jpg",0)

#create our sharpening kernel, it must equal to one eventually

kernel_sharpening = np.array([[-1,-1,-1],
                              [-1, 9,-1],
                              [-1,-1,-1]])

#applying the sharpening kernel to the input image & displaying it.

sharpened = cv2.filter2D(img, -1, kernel_sharpening)
display22(img, sharpened)

# %%
img = cv2.imread("saltpepper.png",0)

#apply the 3x3 median filter on the image

median = cv2.medianBlur(img, 3)
median = cv2.medianBlur(median, 3)
median = cv2.medianBlur(median, 3)
median = cv2.medianBlur(median, 5)
median = cv2.medianBlur(median, 5)
median = cv2.medianBlur(median, 5)
median = cv2.medianBlur(median, 7)

kernel_sharpening = np.array([[-1,-1,-1],
                              [-1, 9,-1],
                              [-1,-1,-1]])


#display image

sharpened = cv2.filter2D(median, -1, kernel_sharpening)
display22(img, sharpened)

# %% [markdown]
# ***BILATERAL FILTER***

# %%
img = cv2.imread("INTER.jpg",0)

bilateral = cv2.bilateralFilter(img,9,75,75)

display22(img, bilateral)

# %% [markdown]
# ***GAUSSIAN BLUR***

# %%
img = cv2.imread("INTER.jpg",0)

gauss = cv2.GaussianBlur(img,(5,5),0)


display22(img, gauss)

# %% [markdown]
# ***LAPLACIAN***

# %%
img = cv2.imread("INTER.jpg",0)

#laplacian

lapl = cv2.Laplacian(img, cv2.CV_64F, ksize=5) #64f es la salida, es un flotante, es un numero grande

display22(img, lapl)

# %%
img = cv2.imread("INTER.jpg",0)

#apply the 3x3 median filter on the image

lapl = cv2.Laplacian(img, cv2.CV_64F, ksize=5)

kernel_sharpening = np.array([[0,  1, 0],
                              [1, -4, 1],
                              [0,  1, 0]])

kernel_sharpening = np.array([[0,  -1, 0],
                              [-1, -4, -1],
                              [0,  -1, 0]])

kernel_sharpening = np.array([[-1,  1, -1],
                              [-1,  8, -1],
                              [-1, -1, -1]])

kernel_sharpening = np.array([[1,  1, 1],
                              [1, -8, 1],
                              [1,  1, 1]])

kernel_sharpening = np.array([[1,  0, -1],
                              [2, -0, -2],
                              [1,  0, -1]])

kernel_sharpening = np.array([[1,  2, 1],
                              [0,  0, 0],
                              [-1,-2, -1]])

#display image

sharpened = cv2.filter2D(img, -1, kernel_sharpening)
display22(img, sharpened)

# %%
img = cv2.imread("RD.jpg",0)

x_sobel = cv2.Sobel(img, cv2.CV_64F,1,0,ksize=5) #si es 1,0 es X y si es 0,1 es Y

display22(img, x_sobel, "original", "Derivate in X")

# %%
img = cv2.imread("RD.jpg",0)

y_sobel = cv2.Sobel(img, cv2.CV_64F,0,1,ksize=5) #si es 1,0 es X y si es 0,1 es Y

display22(img, y_sobel, "original", "Derivate in Y")

# %%
img = cv2.imread("RD.jpg",0)


kernel_sharpening = np.array([[-1, -2, -1],
                              [ 0,  0,  0],
                              [1,   2,  1]])
 
#display image

sharpened = cv2.filter2D(img, -1, kernel_sharpening)
display22(img, sharpened)

# %%
img = cv2.imread("RD.jpg",0)

kernel_sharpening = np.array([[-1, 0, 1],
                              [-2, 0, 2],
                              [-1, 0, 1]])

#display image

sharpened = cv2.filter2D(img, -1, kernel_sharpening)
display22(img, sharpened)
